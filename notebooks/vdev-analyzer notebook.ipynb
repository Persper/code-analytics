# %%
import time
from vdev.vdev_analyzer import VdevAnalyzer

start = time.time()

repo_path = '/Users/zen/repos/zhengxu001/bitcoin'
vdev = VdevAnalyzer(repo_path, 'test.pickle')
await vdev.analyzing()

print("Used time, ", time.time()- start)
# Out:
# {'C': 0.07655821199197577, 'C++': 0.6845279606961665, 'Java': 0.003327686483374751}
# {'C++': {'az': <persper.analytics.analyzer2.Analyzer object at 0x128226908>, 'graph': <persper.analytics.call_commit_graph.CallCommitGraph object at 0x1281773c8>}}
# Start analyzing language,  C++
# Commit #0 e071a3f6c06f41068ad17134189a4ac3073ef76b (First commit
#
#
# git-svn-id: https): Going forward (initial commit).
# Commit #1 465e1d99f25cc7f45efcacfcbb1f95c1c1f9a4ee (Added changelog.txt
#
#
# git-svn-id): Going forward.
# Commit #2 8dca7864f793072701f810e4c5ea12a6e1087085 (No dll's here
#
# git-svn-id: https): Going forward.
# Commit #3 dba0fd9b6a76897bbb42b2b6dcfb3b84b8558936 (tray icon + ask before closing
#
# ): Going forward.
# Commit #4 6d97df0e992dc5015b5327935ab89923d2dc0ba9 (startup shortcut works
#
# git-svn-): Going forward.
# Commit #5 429187c6a8816e6df73f69530d0641ac0dcc514e (Startup folder shortcut opens th): Going forward.
# ...

# %%
print(vdev.developer_profile()['xu@meri.co'])
print(vdev.basic_stats())
# Out:
# {'commits': [<git.Commit "030c5d8c6a4d5de6a317a331b8deadd5a97364ed">], 'email': 'xu@meri.co', 'distrib': {'init_commit_date': datetime.date(2019, 2, 15), 'last_commit_date': datetime.date(2019, 2, 15), 'values': [0.8661305843306119]}, 'dev_value': 0.8661305843306119, 'top_commits': [{'author_email': 'xu@meri.co', 'author_name': 'Xu Zheng', 'author_timestamp': 1550271482, 'committer_email': 'xu.b.zheng@accenture.com', 'committer_name': 'Xu Zheng', 'commit_timestamp': 1551135602, 'hash': '030c5d8c6a4d5de6a317a331b8deadd5a97364ed', 'parent_hashes': ['1da44d2e96cd2461eb25ffd17c417cf2e5aef9de'], 'dev_value': 0.8661305843306119, 'title': 'Squash commits for fast analysis', 'message': 'Squash commits for fast analysis\n'}], 'modules': {'src/wallet/db.cpp': 0.004189250332939093, 'db.cpp': 0.003403132802779296, 'ui.cpp': 0.02353532034021895, 'src/qt/bitcoinamountfield.cpp': 0.009317638631396537, 'src/univalue/lib/univalue.cpp': 0.034258837700134916, 'src/bloom.cpp': 0.0606528494212532, 'src/q
# ...

# %% [markdown]
# ## Reload Pickle

# %%
import pickle 
vdev_load = pickle.load(open('test.pickle', 'rb'))

# %%
await vdev_load.analyzing()
# Out:
# Start analyzing language,  C++
# Saving pickle file

# %%
vdev_load.developer_profile()
# Out:
# {'xu@meri.co': {'commits': [<git.Commit "030c5d8c6a4d5de6a317a331b8deadd5a97364ed">],
#   'email': 'xu@meri.co',
#   'distrib': {'init_commit_date': datetime.date(2019, 2, 15),
#    'last_commit_date': datetime.date(2019, 2, 15),
#    'values': [0.8661305843306119]},
#   'dev_value': 0.8661305843306119,
#   'top_commits': [{'author_email': 'xu@meri.co',
#     'author_name': 'Xu Zheng',
#     'author_timestamp': 1550271482,
#     'committer_email': 'xu.b.zheng@accenture.com',
#     'committer_name': 'Xu Zheng',
#     'commit_timestamp': 1551135602,
#     'hash': '030c5d8c6a4d5de6a317a331b8deadd5a97364ed',
#     'parent_hashes': ['1da44d2e96cd2461eb25ffd17c417cf2e5aef9de'],
#     'dev_value': 0.8661305843306119,
#     'title': 'Squash commits for fast analysis',
#     'message': 'Squash commits for fast analysis\n'}],
#   'modules': {'src/wallet/db.cpp': 0.004189250332939093,
#    'db.cpp': 0.0034031328027792967,
#    'ui.cpp': 0.023535320340218952,
# ...

# %%
vdev_load.basic_stats()
# Out:
# [0.07146847583996349,
#  0.0,
#  0.0,
#  0.001267222440883998,
#  0.0003524165491272559,
#  1.98442868654372e-05,
#  0.0,
#  0.00033016185559163745,
#  0.006188173172260014,
#  0.0,
#  0.0003599544944166453,
#  0.007539314343291681,
#  1.9221018454352793e-05,
#  0.0007739242808584468,
#  0.0,
#  0.00010675700702531316,
#  1.5251001003616164e-05,
#  0.0,
#  0.004652622887089022,
#  0.0,
#  0.0016407661189988339,
#  0.0016114186735598798,
#  0.0005945661690225988,
#  0.0014232764902858029,
#  0.00029183842366153423,
#  0.00031960343733234943,
#  0.002852869662314813,
#  0.0,
#  0.001520608546006502,
#  2.0903518760620547e-05,
#  7.964830992242627e-05,
#  6.25749182857508e-05,
#  0.0005046825849880913,
#  5.4173049706787875e-06,
#  0.0001272170908111702,
#  3.294851385940308e-06,
#  0.0,
#  0.00018830483000591757,
#  0.0,
#  8.542438128669478e-05,
#  0.0004555126147785105,
#  0.0006428601730539026,
#  0.0006386762810651931,
#  0.00014296379815664702,
#  0.00014296379815664702,
# ...
