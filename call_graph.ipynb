# %%
from lxml import etree
from write_graph_to_dot import write_G_to_dot_with_pr

def inspect(node):
    for child in node:
        print(child.tag, child.attrib)

# %%
import networkx as nx

ns = {'srcml': 'http://www.srcML.org/srcML/src', 'pos': 'http://www.srcML.org/srcML/position'}

def handle_variable_decl(node, prev_type, v_to_type):
    # get type
    type_node = node.find('srcml:type', ns)
    type_name = None
    if type_node == None:
        # Enum Def falls into this case
        return prev_type, v_to_type
    elif 'ref' in type_node.attrib:
        assert(type_node.attrib['ref'] == "prev")
        type_name = prev_type
    else:
        type_name = type_node.find('srcml:name', ns).text
        prev_type = type_name
        
    # vectors not supported yet
    if not type_name:
        return prev_type, v_to_type

    # get name
    all_name_nodes = node.findall('srcml:name', ns)
    variable_name = None
    if len(all_name_nodes) > 0 and all_name_nodes[0].text:
        variable_name = all_name_nodes[0].text
    else:
        return prev_type, v_to_type

    # for debug
    # print("-------")
    # print(type_name)
    # print(variable_name)
    # print("-------")
    v_to_type[variable_name] = type_name
    return prev_type, v_to_type


def build_call_graph(h_roots, c_roots):
    G = nx.DiGraph()
    v_to_type = {}
    cl_to_func = {}
    
    for h_root in h_roots:
        print(h_root.attrib['filename'])
        
        class_name = None
        for decl_node in h_root.xpath('./srcml:decl_stmt/srcml:decl', namespaces=ns):
            try:
                type_name = decl_node.find('srcml:type', ns).find('srcml:name', ns).text
                assert(type_name == 'class')
                class_name = decl_node.find('srcml:name', ns).text
            except Error:
                print("Error when get type_name and class_name!")
                continue
            
            cl_to_func[class_name] = set()
            
            for node in decl_node.xpath('.//srcml:argument_list', namespaces=ns):
                parent = node.getparent()
                if parent.tag == '{http://www.srcML.org/srcML/src}call':
                    # if argument_list node is a child of a call node, then continue
                    continue
                
                """
                if parent.tag == '{http://www.srcML.org/srcML/src}decl':
                    print(parent.find('srcml:name', ns).find('pos:position', ns).attrib)
                    
                elif parent.tag == '{http://www.srcML.org/srcML/src}macro':
                    grand_parent = parent.getparent()
                    block_node = grand_parent.find('srcml:block', ns)
                    if block_node:
                        # then this is a function definition
                        # do something
                else:
                    print('------ New Cases Found! --------')
                """
                
                    
                func_name = parent.find('srcml:name', ns).text
                cl_to_func[class_name].add(func_name)
                
            for node in decl_node.xpath('.//srcml:function_decl', namespaces=ns):
                func_name = node.find('srcml:name', ns).text
                cl_to_func[class_name].add(func_name)
                
            prev_type = None
            for node in decl_node.iter():
                if node.tag == '{http://www.srcML.org/srcML/src}decl':
                    prev_type, v_to_type = handle_variable_decl(node, prev_type, v_to_type)
    
    for c_root in c_roots:
        print(c_root.attrib['filename'])
        
        for func_node in c_root.xpath('./srcml:constructor | ./srcml:function', namespaces=ns):
            
            # get caller_id and add it to G
            caller_name_node = func_node.find('srcml:name', ns)
            caller_id = None
            caller_class_name = None
            if caller_name_node.text:
                caller_id = caller_name_node.text
            else:
                caller_class_name = caller_name_node[0].text
                assert(caller_name_node[1].text == "::")
                func_name = caller_name_node[2].text
                caller_id = "{}::{}".format(caller_class_name, func_name)
            assert(caller_id)
            G.add_node(caller_id)
                
            # iterate over function body and handle all function calls and declarations
            prev_type = None
            for node in func_node.iter():
                
                # function call
                if node.tag == '{http://www.srcML.org/srcML/src}call':
                    if node.getparent().tag == '{http://www.srcML.org/srcML/src}member_init_list':
                        # ignore calls within member init list
                        continue
                    callee_name_node = node.find('srcml:name', ns)
                    # print("    Function call found!")
                    
                    # get callee_id
                    callee_id = None
                    if callee_name_node.text:
                        callee_name = callee_name_node.text
                        if caller_class_name and caller_class_name in cl_to_func and callee_name in cl_to_func[caller_class_name]:
                            callee_id = "{}::{}".format(caller_class_name, callee_name)
                        else:
                            callee_id = callee_name
                    else:
                        variable_name = callee_name_node[0].text
                        callee_name = callee_name_node[2].text
                        if variable_name not in v_to_type:
                            # temporary hack
                            print("variable name not in v_to_type: {}".format(variable_name))
                            callee_id = "Unknown::{}".format(callee_name)
                        else:
                            callee_id = "{}::{}".format(v_to_type[variable_name], callee_name)
                        
                    if callee_id not in G:
                        G.add_node(callee_id)
                    G.add_edge(caller_id, callee_id)
                    
                # declaration   
                elif node.tag == '{http://www.srcML.org/srcML/src}decl':
                    prev_type, v_to_type = handle_variable_decl(node, prev_type, v_to_type)
                
    return G, v_to_type

# %%
import glob
import subprocess

h_files = glob.glob('./Sexain-MemController/*.h')
h_roots = []
for h_file in h_files:
    subprocess.call('srcml {} --position --xmlns persper -o {}.xml'.format(h_file, h_file), shell=True)
    tree = etree.parse('{}.xml'.format(h_file))
    h_roots.append(tree.getroot())
    
cc_files = glob.glob('./Sexain-MemController/*.cc')
c_roots = []
for cc_file in cc_files:
    subprocess.call('srcml {} --position --xmlns persper -o {}.xml'.format(cc_file, cc_file), shell=True)
    tree = etree.parse('{}.xml'.format(cc_file))
    c_roots.append(tree.getroot())
    
from cpp_tools import get_func_ranges_cpp
sizes = {}
for cc_file in cc_files:
    with open(cc_file, 'r') as f:
        src = f.read()
        func_ids, func_ranges = get_func_ranges_cpp(src, None)
        for i, func_id in enumerate(func_ids):
            sizes[func_id] = func_ranges[i][1] - func_ranges[i][0] + 1
    
G, _ = build_call_graph(h_roots, c_roots)
pr = nx.pagerank(G.reverse(), alpha=0.85)
pr_size = pagerank_with_sizes(G, sizes)
pr_size_self = pagerank_with_sizes(G, sizes, count_self=True)

"""
write_G_to_dot_with_pr(G, pr_size, 'Sexain_call_graph_v2.dot', header_lines=['nodesep=1.0;\n'])
# !unflatten -l 8 -f -o unflattened_Sexain_call_graph_v2.dot Sexain_call_graph_v2.dot 
# !dot -Tsvg unflattened_Sexain_call_graph_v2.dot -o unflattened_Sexain_call_graph_v2.svg
write_G_to_dot_with_pr(G, pr_size_self, 'Sexain_call_graph_v3.dot', header_lines=['nodesep=1.0;\n'])
# !unflatten -l 8 -f -o unflattened_Sexain_call_graph_v3.dot Sexain_call_graph_v3.dot 
# !dot -Tsvg unflattened_Sexain_call_graph_v3.dot -o unflattened_Sexain_call_graph_v3.svg
"""
# Out:
#   File "<string>", line unknown
# XMLSyntaxError: Namespace prefix pos for tabs on unit is not defined, line 2, column 105

# %%
tree = etree.parse('./Sexain-MemController/addr_trans_controller.h.xml')
h_roots3 = [tree.getroot()]
tree = etree.parse('./test.cc.xml')
c_roots3 = [tree.getroot()]
G3, v_to_type = build_call_graph(h_roots3, c_roots3)
write_graph_to_dot(G3, 'test_call_graph.dot')
# !dot -Tsvg test_call_graph.dot -o test_call_graph.svg

# %%
G4['AddrTransController::DRAMStore']

# %%
from numpy import linalg as LA
import numpy as np

def pagerank(G, alpha=0.85, epsilon=1e-5, max_iters=300):
    ni = {}
    for i, u in enumerate(G):
        ni[u] = i
        
    num_nodes = len(G.nodes())
    P = np.zeros([num_nodes, num_nodes])
    
    for u in G:
        num_out_edges = len(G[u])
        if num_out_edges == 0:
            P[:, ni[u]] = 1 / num_nodes
        else:
            for v in G[u]:
                P[ni[v], ni[u]] = 1 / num_out_edges
            
    p = np.ones(num_nodes) / num_nodes
    v = np.ones(num_nodes) / num_nodes
        
    for i in range(max_iters):
        new_v = alpha * np.dot(P, v) + (1 - alpha) * p
        assert(new_v.shape == (num_nodes,))
        delta = new_v - v
        if LA.norm(delta) < epsilon:
            break
        v = new_v
        
    pr = {}
    for u in G:
        pr[u] = v[ni[u]]
    
    return pr


def pagerank_with_sizes(G, sizes, count_self=False, default_size=3, alpha=0.85, epsilon=1e-5, max_iters=300):
    ni = {}
    for i, u in enumerate(G):
        ni[u] = i
        
    universe_size = 0
    for u in G:
        if u not in sizes:
            sizes[u] = default_size
        universe_size += sizes[u]
        
    num_nodes = len(G.nodes())
    P = np.zeros([num_nodes, num_nodes])
    
    for u in G:
        num_out_edges = len(G[u])
        if num_out_edges == 0:
            P[:, ni[u]] = 1 / num_nodes
        else:
            total_out_sizes = 0
            for v in G[u]:
                total_out_sizes += sizes[v]
            if count_self:
                total_out_sizes += sizes[u]
                P[ni[u], ni[u]] = sizes[u] / total_out_sizes
            for v in G[u]:
                P[ni[v], ni[u]] = sizes[v] / total_out_sizes
            
    p = np.empty(num_nodes)
    for u in G:
        p[ni[u]] = sizes[u] / universe_size

    v = np.ones(num_nodes) / num_nodes
        
    for i in range(max_iters):
        new_v = alpha * np.dot(P, v) + (1 - alpha) * p
        assert(new_v.shape == (num_nodes,))
        delta = new_v - v
        if LA.norm(delta) < epsilon:
            break
        v = new_v
        
    pr = {}
    for u in G:
        pr[u] = v[ni[u]]
    
    return pr

# %%
pr
# Out:
# {'AddrTransController::AddrTransController': 0.010733974488471089,
#  'AddrTransController::BeginCheckpointing': 0.019582085379620567,
#  'AddrTransController::CheckValid': 0.003001572955025558,
#  'AddrTransController::CopyBlockInter': 0.003001572955025558,
#  'AddrTransController::CopyBlockIntra': 0.003001572955025558,
#  'AddrTransController::DRAMStore': 0.03461490089774263,
#  'AddrTransController::DirtyCleaner': 0.009380804220118121,
#  'AddrTransController::DirtyStained': 0.009743041357773544,
#  'AddrTransController::Discard': 0.006842201993183283,
#  'AddrTransController::FinishCheckpointing': 0.015673614132803736,
#  'AddrTransController::FreeClean': 0.012239322672063934,
#  'AddrTransController::FreeLoan': 0.008719518622624808,
#  'AddrTransController::FullBlock': 0.003001572955025558,
#  'AddrTransController::GetAddrInfo': 0.008560479021073403,
#  'AddrTransController::HideClean': 0.009124333748875288,
#  'AddrTransController::HideTemp': 0.00828380683077504,
#  'AddrTransController::IsDRAM': 0.003001572955025558,
#  'AddrTransController::LoadAddr': 0.01797743946001957,
#  'AddrTransController::LoanRevoker': 0.00690643572941555,
#  'AddrTransController::MigrateDRAM': 0.01462288066182698,
#  'AddrTransController::MigrateNVM': 0.029460651186934535,
#  'AddrTransController::MigratePages': 0.08998205037801399,
#  'AddrTransController::NVMStore': 0.06679637643569218,
#  'AddrTransController::Probe': 0.014042550144608841,
#  'AddrTransController::ResetClean': 0.010711152901175646,
#  'AddrTransController::Setup': 0.01525854666814821,
#  'AddrTransController::StoreAddr': 0.10162180757020325,
#  'AddrTransController::SwapBlock': 0.003001572955025558,
#  'AddrTransController::in_checkpointing': 0.003001572955025558,
#  'AddrTransTable::AddBlockRead': 0.003001572955025558,
#  'AddrTransTable::AddBlockWrite': 0.003001572955025558,
#  'AddrTransTable::At': 0.003001572955025558,
#  'AddrTransTable::ClearStats': 0.0040495895200050504,
#  'AddrTransTable::Contains': 0.003001572955025558,
#  'AddrTransTable::GetFront': 0.003001572955025558,
#  'AddrTransTable::GetLength': 0.003001572955025558,
#  'AddrTransTable::GetQueue': 0.003001572955025558,
#  'AddrTransTable::IsEmpty': 0.003001572955025558,
#  'AddrTransTable::Lookup': 0.009291053130890629,
#  'AddrTransTable::Reset': 0.004526833851145535,
#  'AddrTransTable::Setup': 0.012799630326691538,
#  'AddrTransTable::ShiftState': 0.008972091567635999,
#  'AddrTransTable::ToAddr': 0.003001572955025558,
#  'AddrTransTable::ToTag': 0.003001572955025558,
#  'AddrTransTable::Translate': 0.003001572955025558,
#  'AddrTransTable::VisitQueue': 0.003001572955025558,
#  'AddrTransTable::entries': 0.003001572955025558,
#  'AddrTransTable::length': 0.003001572955025558,
#  'DPRINTF': 0.003001572955025558,
#  'Empty': 0.003001572955025558,
#  'IndexQueue::Accept': 0.006829111714081095,
#  'IndexQueue::Back': 0.003001572955025558,
#  'IndexQueue::BackNode': 0.003001572955025558,
#  'IndexQueue::Empty': 0.003001572955025558,
#  'IndexQueue::Front': 0.003001572955025558,
#  'IndexQueue::PushBack': 0.012009820741489603,
#  'IndexQueue::Remove': 0.008182281982434066,
#  'MemStore::GetReadLatency': 0.003001572955025558,
#  'MemStore::GetWriteLatency': 0.003001572955025558,
#  'MemStore::OnATTWriteHit': 0.003001572955025558,
#  'MemStore::OnATTWriteMiss': 0.003001572955025558,
#  'MemStore::OnEpochEnd': 0.003001572955025558,
#  'MemStore::ckDRAMWriteHit': 0.003001572955025558,
#  'MemStore::statsDRAMWrites': 0.003001572955025558,
#  'MemStore::statsNVMWrites': 0.003001572955025558,
#  'MigrationController::AddDRAMPageRead': 0.003001572955025558,
#  'MigrationController::AddDRAMPageWrite': 0.003001572955025558,
#  'MigrationController::AddToBlockList': 0.004719270724240957,
#  'MigrationController::Clear': 0.010202984713869987,
#  'MigrationController::Contains': 0.003001572955025558,
#  'MigrationController::ExtractDRAMPage': 0.008805016463074054,
#  'MigrationController::ExtractNVMPage': 0.008805016463074054,
#  'MigrationController::FillDRAMPageHeap': 0.005402759788358018,
#  'MigrationController::FillNVMPageHeap': 0.007877128279060588,
#  'MigrationController::Free': 0.003001572955025558,
#  'MigrationController::InputBlocks': 0.023556242776344515,
#  'MigrationController::LookupPage': 0.003001572955025558,
#  'MigrationController::PageAlign': 0.003001572955025558,
#  'MigrationController::Setup': 0.003001572955025558,
#  'MigrationController::ShiftState': 0.003001572955025558,
#  'MigrationController::Translate': 0.003001572955025558,
#  'MigrationController::num_dirty_entries': 0.003001572955025558,
#  'MigrationController::num_entries': 0.003001572955025558,
#  'MigrationController::page_blocks': 0.003001572955025558,
#  'MigrationController::page_size': 0.003001572955025558,
#  'MigrationController::ptt_capacity': 0.003001572955025558,
#  'MigrationController::ptt_length': 0.003001572955025558,
#  'NVMPage::blocks': 0.003001572955025558,
#  'PageAlign': 0.003001572955025558,
#  'PopFront': 0.003001572955025558,
#  'Profiler::AddBlockMoveInter': 0.003001572955025558,
#  'Profiler::AddBlockMoveIntra': 0.003001572955025558,
#  'Profiler::AddBufferOp': 0.003001572955025558,
#  'Profiler::AddLatency': 0.003001572955025558,
#  'Profiler::AddPageMoveInter': 0.003001572955025558,
#  'Profiler::AddPageMoveIntra': 0.003001572955025558,
#  'Profiler::AddTableOp': 0.003001572955025558,
#  'Profiler::clear_ignore_latency': 0.003001572955025558,
#  'Profiler::set_ignore_latency': 0.003001572955025558,
#  'PushBack': 0.003001572955025558,
#  'QueueVisitor::Visit': 0.003001572955025558,
#  'Remove': 0.003001572955025558,
#  'SetBack': 0.003001572955025558,
#  'SetFront': 0.003001572955025558,
#  'Unknown::DirtyStained': 0.003001572955025558,
#  'Unknown::FreeLoan': 0.003001572955025558,
#  'Unknown::HideTemp': 0.003001572955025558,
#  'Unknown::att_': 0.003001572955025558,
#  'Unknown::begin': 0.003001572955025558,
#  'Unknown::clear': 0.003001572955025558,
#  'Unknown::count': 0.003001572955025558,
#  'Unknown::empty': 0.003001572955025558,
#  'Unknown::end': 0.003001572955025558,
#  'Unknown::erase': 0.003001572955025558,
#  'Unknown::find': 0.003001572955025558,
#  'Unknown::front': 0.003001572955025558,
#  'Unknown::pop_back': 0.003001572955025558,
#  'Unknown::push_back': 0.003001572955025558,
#  'Unknown::second': 0.003001572955025558,
#  'Unknown::size': 0.003001572955025558,
#  'VersionBuffer::At': 0.003001572955025558,
#  'VersionBuffer::ClearBackup': 0.011584538657150097,
#  'VersionBuffer::FreeSlot': 0.008607564066773567,
#  'VersionBuffer::Index': 0.003001572955025558,
#  'VersionBuffer::Size': 0.003001572955025558,
#  'VersionBuffer::SlotAlloc': 0.011584538657150098,
#  'VersionBuffer::SlotBackup': 0.011159256572810593,
#  'VersionBuffer::addr_base': 0.003001572955025558,
#  'VersionBuffer::set_addr_base': 0.003001572955025558,
#  'assert': 0.003001572955025558,
#  'begin': 0.003001572955025558,
#  'clear': 0.003001572955025558,
#  'count': 0.003001572955025558,
#  'empty': 0.003001572955025558,
#  'end': 0.003001572955025558,
#  'erase': 0.003001572955025558,
#  'find': 0.003001572955025558,
#  'insert': 0.003001572955025558,
#  'make_heap': 0.003001572955025558,
#  'pop_heap': 0.003001572955025558,
#  'size': 0.003001572955025558}

# %%
pr_size
# Out:
# {'AddrTransController::AddrTransController': 0.0053532151895998425,
#  'AddrTransController::BeginCheckpointing': 0.0053532151895998425,
#  'AddrTransController::CheckValid': 0.005456647377649693,
#  'AddrTransController::CopyBlockInter': 0.0066853352611887448,
#  'AddrTransController::CopyBlockIntra': 0.0073249034412626139,
#  'AddrTransController::DRAMStore': 0.0065944014461980505,
#  'AddrTransController::DirtyCleaner': 0.0053532151895998425,
#  'AddrTransController::DirtyStained': 0.0059737519567257067,
#  'AddrTransController::Discard': 0.0069979256817092172,
#  'AddrTransController::FinishCheckpointing': 0.0053532151895998425,
#  'AddrTransController::FreeClean': 0.0070496420361705874,
#  'AddrTransController::FreeLoan': 0.006871070789163141,
#  'AddrTransController::FullBlock': 0.0056210720601110112,
#  'AddrTransController::GetAddrInfo': 0.0053532151895998425,
#  'AddrTransController::HideClean': 0.0060125355046710734,
#  'AddrTransController::HideTemp': 0.0059737519567257067,
#  'AddrTransController::IsDRAM': 0.0069973826343231113,
#  'AddrTransController::LoadAddr': 0.0053532151895998425,
#  'AddrTransController::LoanRevoker': 0.0053532151895998425,
#  'AddrTransController::MigrateDRAM': 0.0060643114824425644,
#  'AddrTransController::MigrateNVM': 0.0068322954787127087,
#  'AddrTransController::MigratePages': 0.0053532151895998425,
#  'AddrTransController::NVMStore': 0.0079390198908461107,
#  'AddrTransController::Probe': 0.0053532151895998425,
#  'AddrTransController::ResetClean': 0.005896184860834975,
#  'AddrTransController::Setup': 0.0064246426716445225,
#  'AddrTransController::StoreAddr': 0.0053532151895998425,
#  'AddrTransController::SwapBlock': 0.005752551273999167,
#  'AddrTransController::in_checkpointing': 0.0099996870465741908,
#  'AddrTransTable::AddBlockRead': 0.0056782877806136577,
#  'AddrTransTable::AddBlockWrite': 0.0054695658334359409,
#  'AddrTransTable::At': 0.0095919095050743738,
#  'AddrTransTable::ClearStats': 0.0061563357085751523,
#  'AddrTransTable::Contains': 0.0064053996833717732,
#  'AddrTransTable::GetFront': 0.0056210720601110112,
#  'AddrTransTable::GetLength': 0.0061897990635324581,
#  'AddrTransTable::GetQueue': 0.010589363354221882,
#  'AddrTransTable::IsEmpty': 0.0062752806495263175,
#  'AddrTransTable::Lookup': 0.011617162914952956,
#  'AddrTransTable::Reset': 0.0090953236372190958,
#  'AddrTransTable::Setup': 0.008473143283170748,
#  'AddrTransTable::ShiftState': 0.019740577456439805,
#  'AddrTransTable::ToAddr': 0.0082422292354132932,
#  'AddrTransTable::ToTag': 0.0071686302368023803,
#  'AddrTransTable::Translate': 0.0059461446511248281,
#  'AddrTransTable::VisitQueue': 0.0057062535843994053,
#  'AddrTransTable::entries': 0.0054385467447409692,
#  'AddrTransTable::length': 0.0061897990635324581,
#  'DPRINTF': 0.0060760458128739751,
#  'Empty': 0.0063818467051837639,
#  'IndexQueue::Accept': 0.0053532151895998425,
#  'IndexQueue::Back': 0.0070219211568040996,
#  'IndexQueue::BackNode': 0.0061117179019654147,
#  'IndexQueue::Empty': 0.0061117179019654147,
#  'IndexQueue::Front': 0.0085389265815352458,
#  'IndexQueue::PushBack': 0.0053532151895998425,
#  'IndexQueue::Remove': 0.0053532151895998425,
#  'MemStore::GetReadLatency': 0.0056782877806136577,
#  'MemStore::GetWriteLatency': 0.0056210720601110112,
#  'MemStore::OnATTWriteHit': 0.0056210720601110112,
#  'MemStore::OnATTWriteMiss': 0.0056210720601110112,
#  'MemStore::OnEpochEnd': 0.0058240099765853696,
#  'MemStore::ckDRAMWriteHit': 0.0055047214162749127,
#  'MemStore::statsDRAMWrites': 0.005456647377649693,
#  'MemStore::statsNVMWrites': 0.005456647377649693,
#  'MigrationController::AddDRAMPageRead': 0.0056782877806136577,
#  'MigrationController::AddDRAMPageWrite': 0.005456647377649693,
#  'MigrationController::AddToBlockList': 0.0090134942847652187,
#  'MigrationController::Clear': 0.0074948699068673394,
#  'MigrationController::Contains': 0.0059220922238740221,
#  'MigrationController::ExtractDRAMPage': 0.0057229852618780573,
#  'MigrationController::ExtractNVMPage': 0.0057229852618780573,
#  'MigrationController::FillDRAMPageHeap': 0.0070306931437502333,
#  'MigrationController::FillNVMPageHeap': 0.0067346676224295764,
#  'MigrationController::Free': 0.0058365226490975954,
#  'MigrationController::InputBlocks': 0.0060358676307288566,
#  'MigrationController::LookupPage': 0.0062873884435738908,
#  'MigrationController::PageAlign': 0.0058588836645102234,
#  'MigrationController::Setup': 0.0055074067982350955,
#  'MigrationController::ShiftState': 0.0061917529702037021,
#  'MigrationController::Translate': 0.0056782877806136577,
#  'MigrationController::num_dirty_entries': 0.0059220922238740221,
#  'MigrationController::num_entries': 0.0054385467447409692,
#  'MigrationController::page_blocks': 0.0059907142577328484,
#  'MigrationController::page_size': 0.0080595938989750284,
#  'MigrationController::ptt_capacity': 0.0054385467447409692,
#  'MigrationController::ptt_length': 0.0060074237790151488,
#  'NVMPage::blocks': 0.0056492407109204994,
#  'PageAlign': 0.0056492407109204994,
#  'PopFront': 0.0063818467051837639,
#  'Profiler::AddBlockMoveInter': 0.0055074067982350955,
#  'Profiler::AddBlockMoveIntra': 0.0055074067982350955,
#  'Profiler::AddBufferOp': 0.0097472382603989941,
#  'Profiler::AddLatency': 0.0059461446511248281,
#  'Profiler::AddPageMoveInter': 0.0065716282416516045,
#  'Profiler::AddPageMoveIntra': 0.0058365226490975954,
#  'Profiler::AddTableOp': 0.013817871273010891,
#  'Profiler::clear_ignore_latency': 0.0055927383533762205,
#  'Profiler::set_ignore_latency': 0.0055927383533762205,
#  'PushBack': 0.010589363354221882,
#  'QueueVisitor::Visit': 0.0076287233266965609,
#  'Remove': 0.0095607318386379588,
#  'SetBack': 0.0070219211568040996,
#  'SetFront': 0.0070219211568040996,
#  'Unknown::DirtyStained': 0.0068702206143309887,
#  'Unknown::FreeLoan': 0.0068702206143309869,
#  'Unknown::HideTemp': 0.0068702206143309887,
#  'Unknown::att_': 0.0083872260390621348,
#  'Unknown::begin': 0.011685009936501371,
#  'Unknown::clear': 0.0060883207821538516,
#  'Unknown::count': 0.0063818467051837639,
#  'Unknown::empty': 0.0068655490076605947,
#  'Unknown::end': 0.013095135512311732,
#  'Unknown::erase': 0.0081506062628275977,
#  'Unknown::find': 0.0067633407654102036,
#  'Unknown::front': 0.0065695234863399378,
#  'Unknown::pop_back': 0.0065695234863399378,
#  'Unknown::push_back': 0.011599238533180792,
#  'Unknown::second': 0.0064980114966664265,
#  'Unknown::size': 0.0056492407109204994,
#  'VersionBuffer::At': 0.0063797168637720406,
#  'VersionBuffer::ClearBackup': 0.0084918471028366943,
#  'VersionBuffer::FreeSlot': 0.010678959976430114,
#  'VersionBuffer::Index': 0.0076895780958042247,
#  'VersionBuffer::Size': 0.0064909692581481999,
#  'VersionBuffer::SlotAlloc': 0.0084555992322734117,
#  'VersionBuffer::SlotBackup': 0.0097922890527327305,
#  'VersionBuffer::addr_base': 0.0064909692581481999,
#  'VersionBuffer::set_addr_base': 0.0064909692581481999,
#  'assert': 0.030705057240116778,
#  'begin': 0.0074108753541946102,
#  'clear': 0.0063843736800224121,
#  'count': 0.0063933608538962843,
#  'empty': 0.0063797168637720406,
#  'end': 0.008720736586226796,
#  'erase': 0.0087160797699764227,
#  'find': 0.0076895780958042247,
#  'insert': 0.0097472382603989941,
#  'make_heap': 0.0076930777434961323,
#  'pop_heap': 0.0065695234863399378,
#  'size': 0.0063843736800224121}

# %%
pr_size_self
# Out:
# {'AddrTransController::AddrTransController': 0.0043065126313039572,
#  'AddrTransController::BeginCheckpointing': 0.0037515644729885808,
#  'AddrTransController::CheckValid': 0.0037425655379979494,
#  'AddrTransController::CopyBlockInter': 0.0050819676041651152,
#  'AddrTransController::CopyBlockIntra': 0.0058136187066251009,
#  'AddrTransController::DRAMStore': 0.012850688017354164,
#  'AddrTransController::DirtyCleaner': 0.0045389316444671797,
#  'AddrTransController::DirtyStained': 0.0088295184156656562,
#  'AddrTransController::Discard': 0.018731833597120925,
#  'AddrTransController::FinishCheckpointing': 0.0049477069608402967,
#  'AddrTransController::FreeClean': 0.01171459770185463,
#  'AddrTransController::FreeLoan': 0.010760392650042113,
#  'AddrTransController::FullBlock': 0.0040420554279740383,
#  'AddrTransController::GetAddrInfo': 0.0039064551389500759,
#  'AddrTransController::HideClean': 0.0094942001458155224,
#  'AddrTransController::HideTemp': 0.0089927993148888816,
#  'AddrTransController::IsDRAM': 0.0053879938670342419,
#  'AddrTransController::LoadAddr': 0.010028025805025079,
#  'AddrTransController::LoanRevoker': 0.0045389316444671788,
#  'AddrTransController::MigrateDRAM': 0.01297747839469697,
#  'AddrTransController::MigrateNVM': 0.018466220914411538,
#  'AddrTransController::MigratePages': 0.015910646838735321,
#  'AddrTransController::NVMStore': 0.023896491062422313,
#  'AddrTransController::Probe': 0.010068462323733911,
#  'AddrTransController::ResetClean': 0.0080522186388076716,
#  'AddrTransController::Setup': 0.0089866637130749834,
#  'AddrTransController::StoreAddr': 0.011540220250770004,
#  'AddrTransController::SwapBlock': 0.0040411766762960752,
#  'AddrTransController::in_checkpointing': 0.0086824689674460075,
#  'AddrTransTable::AddBlockRead': 0.0039504665542113935,
#  'AddrTransTable::AddBlockWrite': 0.0038191339828640989,
#  'AddrTransTable::At': 0.0083966407892094863,
#  'AddrTransTable::ClearStats': 0.00859149333664503,
#  'AddrTransTable::Contains': 0.0047255632702506321,
#  'AddrTransTable::GetFront': 0.0040420554279740383,
#  'AddrTransTable::GetLength': 0.0043221436476353235,
#  'AddrTransTable::GetQueue': 0.0084023705308222917,
#  'AddrTransTable::IsEmpty': 0.004793760376775767,
#  'AddrTransTable::Lookup': 0.019428144515534415,
#  'AddrTransTable::Reset': 0.01145592238521605,
#  'AddrTransTable::Setup': 0.013338801135871466,
#  'AddrTransTable::ShiftState': 0.030792340127289521,
#  'AddrTransTable::ToAddr': 0.0065783465486098178,
#  'AddrTransTable::ToTag': 0.0058569955192081099,
#  'AddrTransTable::Translate': 0.0044181138809787201,
#  'AddrTransTable::VisitQueue': 0.0039326902471435669,
#  'AddrTransTable::entries': 0.0037555338753616986,
#  'AddrTransTable::length': 0.0043221436476353235,
#  'DPRINTF': 0.0046214989373913459,
#  'Empty': 0.004493773552339945,
#  'IndexQueue::Accept': 0.010413431357998413,
#  'IndexQueue::Back': 0.0051355050535207237,
#  'IndexQueue::BackNode': 0.0042344822312217131,
#  'IndexQueue::Empty': 0.0042344822312217131,
#  'IndexQueue::Front': 0.0060375887814186095,
#  'IndexQueue::PushBack': 0.0085414454179483894,
#  'IndexQueue::Remove': 0.014138487175920691,
#  'MemStore::GetReadLatency': 0.0039504665542113935,
#  'MemStore::GetWriteLatency': 0.0040420554279740383,
#  'MemStore::OnATTWriteHit': 0.0040420554279740383,
#  'MemStore::OnATTWriteMiss': 0.0040420554279740383,
#  'MemStore::OnEpochEnd': 0.0039248695172401527,
#  'MemStore::ckDRAMWriteHit': 0.0037973295463166511,
#  'MemStore::statsDRAMWrites': 0.0037425655379979494,
#  'MemStore::statsNVMWrites': 0.0037425655379979494,
#  'MigrationController::AddDRAMPageRead': 0.0039504665542113935,
#  'MigrationController::AddDRAMPageWrite': 0.0037425655379979494,
#  'MigrationController::AddToBlockList': 0.013993540450942785,
#  'MigrationController::Clear': 0.0133600363453677,
#  'MigrationController::Contains': 0.0041449872758534548,
#  'MigrationController::ExtractDRAMPage': 0.0081959294449409185,
#  'MigrationController::ExtractNVMPage': 0.0081959294449409185,
#  'MigrationController::FillDRAMPageHeap': 0.013825031979991454,
#  'MigrationController::FillNVMPageHeap': 0.011535313906472545,
#  'MigrationController::Free': 0.004154984095603889,
#  'MigrationController::InputBlocks': 0.010853387226136733,
#  'MigrationController::LookupPage': 0.0044506710287459958,
#  'MigrationController::PageAlign': 0.0039064551389500759,
#  'MigrationController::Setup': 0.0038597971688391821,
#  'MigrationController::ShiftState': 0.0044240293634028698,
#  'MigrationController::Translate': 0.0039504665542113935,
#  'MigrationController::num_dirty_entries': 0.0041449872758534548,
#  'MigrationController::num_entries': 0.0037555338753616986,
#  'MigrationController::page_blocks': 0.0044403731632363594,
#  'MigrationController::page_size': 0.0059591262458889736,
#  'MigrationController::ptt_capacity': 0.0037555338753616986,
#  'MigrationController::ptt_length': 0.0043261130500084413,
#  'NVMPage::blocks': 0.0039385713843346441,
#  'PageAlign': 0.0039385713843346441,
#  'PopFront': 0.004493773552339945,
#  'Profiler::AddBlockMoveInter': 0.0038597971688391821,
#  'Profiler::AddBlockMoveIntra': 0.0038597971688391821,
#  'Profiler::AddBufferOp': 0.0075350072978608556,
#  'Profiler::AddLatency': 0.0044181138809787201,
#  'Profiler::AddPageMoveInter': 0.0048364479210088107,
#  'Profiler::AddPageMoveIntra': 0.004154984095603889,
#  'Profiler::AddTableOp': 0.010926687159809257,
#  'Profiler::clear_ignore_latency': 0.0040409229429941695,
#  'Profiler::set_ignore_latency': 0.0040409229429941695,
#  'PushBack': 0.0084023705308222917,
#  'QueueVisitor::Visit': 0.0051365659591195998,
#  'Remove': 0.0074830050796890601,
#  'SetBack': 0.0051355050535207237,
#  'SetFront': 0.0051355050535207237,
#  'Unknown::DirtyStained': 0.0045389316444671797,
#  'Unknown::FreeLoan': 0.0045389316444671788,
#  'Unknown::HideTemp': 0.0045389316444671797,
#  'Unknown::att_': 0.0055034551877276459,
#  'Unknown::begin': 0.0090831927059164541,
#  'Unknown::clear': 0.0042558719266116325,
#  'Unknown::count': 0.004493773552339945,
#  'Unknown::empty': 0.0050683040459532777,
#  'Unknown::end': 0.010459464770300818,
#  'Unknown::erase': 0.0061067330153046972,
#  'Unknown::find': 0.0049506801655910737,
#  'Unknown::front': 0.0047041407628253462,
#  'Unknown::pop_back': 0.0047041407628253462,
#  'Unknown::push_back': 0.0093672002634525506,
#  'Unknown::second': 0.0045887722525405055,
#  'Unknown::size': 0.0039385713843346441,
#  'VersionBuffer::At': 0.0045076608219442454,
#  'VersionBuffer::ClearBackup': 0.014133552952304609,
#  'VersionBuffer::FreeSlot': 0.01417099575718261,
#  'VersionBuffer::Index': 0.0057225109321587461,
#  'VersionBuffer::Size': 0.0043065126313039572,
#  'VersionBuffer::SlotAlloc': 0.010978910470308367,
#  'VersionBuffer::SlotBackup': 0.012953029475269114,
#  'VersionBuffer::addr_base': 0.0043065126313039572,
#  'VersionBuffer::set_addr_base': 0.0043065126313039572,
#  'assert': 0.027141537454600625,
#  'begin': 0.0053869044669088212,
#  'clear': 0.0044536517461712874,
#  'count': 0.0045181850091458265,
#  'empty': 0.0045076608219442454,
#  'end': 0.0066017545771233218,
#  'erase': 0.0066557636528962807,
#  'find': 0.0057225109321587461,
#  'insert': 0.0075350072978608556,
#  'make_heap': 0.0056904053401785077,
#  'pop_heap': 0.0047041407628253462,
#  'size': 0.0044536517461712874}

# %%
sizes
# Out:
# {'AddrTransController::AddrTransController': 3,
#  'AddrTransController::BeginCheckpointing': 3,
#  'AddrTransController::CheckValid': 3,
#  'AddrTransController::CopyBlockInter': 3,
#  'AddrTransController::CopyBlockIntra': 3,
#  'AddrTransController::DRAMStore': 36,
#  'AddrTransController::DirtyCleaner': 3,
#  'AddrTransController::DirtyStained': 16,
#  'AddrTransController::Discard': 32,
#  'AddrTransController::FinishCheckpointing': 7,
#  'AddrTransController::FreeClean': 19,
#  'AddrTransController::FreeLoan': 17,
#  'AddrTransController::FullBlock': 3,
#  'AddrTransController::GetAddrInfo': 3,
#  'AddrTransController::HideClean': 17,
#  'AddrTransController::HideTemp': 16,
#  'AddrTransController::IsDRAM': 3,
#  'AddrTransController::LoadAddr': 26,
#  'AddrTransController::LoanRevoker': 3,
#  'AddrTransController::MigrateDRAM': 25,
#  'AddrTransController::MigrateNVM': 52,
#  'AddrTransController::MigratePages': 64,
#  'AddrTransController::NVMStore': 75,
#  'AddrTransController::Probe': 21,
#  'AddrTransController::ResetClean': 14,
#  'AddrTransController::Setup': 12,
#  'AddrTransController::StoreAddr': 43,
#  'AddrTransController::SwapBlock': 3,
#  'AddrTransController::in_checkpointing': 3,
#  'AddrTransTable::AddBlockRead': 3,
#  'AddrTransTable::AddBlockWrite': 3,
#  'AddrTransTable::At': 3,
#  'AddrTransTable::ClearStats': 9,
#  'AddrTransTable::Contains': 3,
#  'AddrTransTable::GetFront': 3,
#  'AddrTransTable::GetLength': 3,
#  'AddrTransTable::GetQueue': 3,
#  'AddrTransTable::IsEmpty': 3,
#  'AddrTransTable::Lookup': 15,
#  'AddrTransTable::Reset': 7,
#  'AddrTransTable::Setup': 16,
#  'AddrTransTable::ShiftState': 13,
#  'AddrTransTable::ToAddr': 3,
#  'AddrTransTable::ToTag': 3,
#  'AddrTransTable::Translate': 3,
#  'AddrTransTable::VisitQueue': 3,
#  'AddrTransTable::entries': 3,
#  'AddrTransTable::length': 3,
#  'DPRINTF': 3,
#  'Empty': 3,
#  'IndexQueue::Accept': 11,
#  'IndexQueue::Back': 3,
#  'IndexQueue::BackNode': 3,
#  'IndexQueue::Empty': 3,
#  'IndexQueue::Front': 3,
#  'IndexQueue::PushBack': 15,
#  'IndexQueue::Remove': 25,
#  'MemStore::GetReadLatency': 3,
#  'MemStore::GetWriteLatency': 3,
#  'MemStore::OnATTWriteHit': 3,
#  'MemStore::OnATTWriteMiss': 3,
#  'MemStore::OnEpochEnd': 3,
#  'MemStore::ckDRAMWriteHit': 3,
#  'MemStore::statsDRAMWrites': 3,
#  'MemStore::statsNVMWrites': 3,
#  'MigrationController::AddDRAMPageRead': 3,
#  'MigrationController::AddDRAMPageWrite': 3,
#  'MigrationController::AddToBlockList': 8,
#  'MigrationController::Clear': 24,
#  'MigrationController::Contains': 3,
#  'MigrationController::ExtractDRAMPage': 13,
#  'MigrationController::ExtractNVMPage': 13,
#  'MigrationController::FillDRAMPageHeap': 17,
#  'MigrationController::FillNVMPageHeap': 14,
#  'MigrationController::Free': 3,
#  'MigrationController::InputBlocks': 24,
#  'MigrationController::LookupPage': 3,
#  'MigrationController::PageAlign': 3,
#  'MigrationController::Setup': 3,
#  'MigrationController::ShiftState': 3,
#  'MigrationController::Translate': 3,
#  'MigrationController::num_dirty_entries': 3,
#  'MigrationController::num_entries': 3,
#  'MigrationController::page_blocks': 3,
#  'MigrationController::page_size': 3,
#  'MigrationController::ptt_capacity': 3,
#  'MigrationController::ptt_length': 3,
#  'NVMPage::blocks': 3,
#  'PageAlign': 3,
#  'PopFront': 3,
#  'Profiler::AddBlockMoveInter': 3,
#  'Profiler::AddBlockMoveIntra': 3,
#  'Profiler::AddBufferOp': 3,
#  'Profiler::AddLatency': 3,
#  'Profiler::AddPageMoveInter': 3,
#  'Profiler::AddPageMoveIntra': 3,
#  'Profiler::AddTableOp': 3,
#  'Profiler::clear_ignore_latency': 3,
#  'Profiler::set_ignore_latency': 3,
#  'PushBack': 3,
#  'QueueVisitor::Visit': 3,
#  'Remove': 3,
#  'SetBack': 3,
#  'SetFront': 3,
#  'Unknown::DirtyStained': 3,
#  'Unknown::FreeLoan': 3,
#  'Unknown::HideTemp': 3,
#  'Unknown::att_': 3,
#  'Unknown::begin': 3,
#  'Unknown::clear': 3,
#  'Unknown::count': 3,
#  'Unknown::empty': 3,
#  'Unknown::end': 3,
#  'Unknown::erase': 3,
#  'Unknown::find': 3,
#  'Unknown::front': 3,
#  'Unknown::pop_back': 3,
#  'Unknown::push_back': 3,
#  'Unknown::second': 3,
#  'Unknown::size': 3,
#  'VersionBuffer::At': 3,
#  'VersionBuffer::ClearBackup': 20,
#  'VersionBuffer::FreeSlot': 9,
#  'VersionBuffer::Index': 3,
#  'VersionBuffer::Size': 3,
#  'VersionBuffer::SlotAlloc': 9,
#  'VersionBuffer::SlotBackup': 11,
#  'VersionBuffer::addr_base': 3,
#  'VersionBuffer::set_addr_base': 3,
#  'assert': 3,
#  'begin': 3,
#  'clear': 3,
#  'count': 3,
#  'empty': 3,
#  'end': 3,
#  'erase': 3,
#  'find': 3,
#  'insert': 3,
#  'make_heap': 3,
#  'pop_heap': 3,
#  'size': 3}
